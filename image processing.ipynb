# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1=cv2.imread("C:\\Users\\user\\OneDrive\\Desktop\\rose.jpg")
img2=cv2.imread("C:\\Users\\user\\OneDrive\\Desktop\\butterfly.jpg")

# %%
img1
img2
# Out:
# array([[[22, 65, 38],
#         [23, 66, 39],
#         [23, 66, 39],
#         ...,
#         [21, 74, 31],
#         [22, 75, 32],
#         [21, 76, 31]],
#
#        [[23, 66, 39],
#         [23, 66, 39],
#         [23, 66, 39],
#         ...,
#         [22, 75, 32],
#         [22, 75, 32],
#         [21, 76, 31]],
#
#        [[23, 66, 39],
#         [23, 66, 39],
#         [23, 66, 39],
#         ...,
#         [22, 75, 32],
#         [23, 76, 33],
#         [22, 77, 32]],
#
#        ...,
#
#        [[24, 53, 28],
#         [24, 53, 28],
#         [25, 54, 29],
#         ...,
#         [32, 55, 33],
#         [36, 58, 34],
#         [36, 58, 34]],
#
#        [[24, 53, 28],
#         [24, 53, 28],
#         [25, 54, 29],
#         ...,
#         [31, 54, 32],
#         [35, 57, 33],
#         [35, 57, 33]],
#
#        [[24, 53, 28],
#         [24, 53, 28],
#         [24, 53, 28],
#         ...,
#         [30, 53, 31],
#         [35, 57, 33],
#         [35, 57, 33]]], dtype=uint8)

# %%
img1.shape
img2.shape
# Out:
# (853, 1170, 3)

# %%
plt.subplot(1,2,1),plt.imshow(img1),plt.title('image-1')
plt.subplot(1,2,2),plt.imshow(img2),plt.title('image-2')
# Out:
# (<AxesSubplot:title={'center':'image-2'}>,
# ...
#  Text(0.5, 1.0, 'image-2'))

# %%
red_channel=img1[:,:,0]
green_channel=img1[:,:,1]
blue_channel=img1[:,:,2]

# %%
plt.subplot(1,3,1),plt.imshow(red_channel),plt.title('RED COMPONENT')
# Out:
# (<AxesSubplot:title={'center':'RED COMPONENT'}>,
# ...
#  Text(0.5, 1.0, 'RED COMPONENT'))

# %%
plt.subplot(1,3,1),plt.imshow(green_channel),plt.title('GREEN COMPONENT')
# Out:
# (<AxesSubplot:title={'center':'GREEN COMPONENT'}>,
# ...
#  Text(0.5, 1.0, 'GREEN COMPONENT'))

# %%
plt.subplot(1,3,1),plt.imshow(blue_channel),plt.title('BLUE COMPONENT')
# Out:
# (<AxesSubplot:title={'center':'BLUE COMPONENT'}>,
# ...
#  Text(0.5, 1.0, 'BLUE COMPONENT'))

# %%
plt.subplot(2,2,1),plt.imshow(red_channel),plt.title('RED COMPONENT')
plt.subplot(2,2,2),plt.imshow(green_channel),plt.title('GREEN COMPONENT')
plt.subplot(2,2,3),plt.imshow(blue_channel),plt.title('BLUE COMPONENT')
# Out:
# (<AxesSubplot:title={'center':'BLUE COMPONENT'}>,
# ...
#  Text(0.5, 1.0, 'BLUE COMPONENT'))

# %%
red_channel=img2[:,:,0]
green_channel=img2[:,:,1]
blue_channel=img2[:,:,2]

# %%
plt.subplot(2,2,1),plt.imshow(red_channel),plt.title('RED COMPONENT')
plt.subplot(2,2,2),plt.imshow(green_channel),plt.title('GREEN COMPONENT')
plt.subplot(2,2,3),plt.imshow(blue_channel),plt.title('BLUE COMPONENT')
# Out:
# (<AxesSubplot:title={'center':'BLUE COMPONENT'}>,
# ...
#  Text(0.5, 1.0, 'BLUE COMPONENT'))
